# %%
import cv2

# %%
def generate_dataset():
    face_classifier = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
    
    def face_cropped(img):
        gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        faces = face_classifier.detectMultiScale(gray, 1.3, 5)
        
        if faces == ():
            return None
        for(x,y,w,h) in faces:
            cropped_face = img[y:y+h,x:x+w]
        return cropped_face
    
    cap = cv2.VideoCapture(0)
    img_id=40
    
    
    while True:
        ret,frame = cap.read()
        if face_cropped(frame) is not None:
            img_id+=1
            face = cv2.resize(face_cropped(frame), (200,200))
            face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)
            #file_name_path = "data/"+"user3."+str(img_id)+".jpg"
            file_name_path = "Images for visualization/"+str(img_id)+'.jpg'
            cv2.imwrite(file_name_path, face)
            cv2.putText(face, str(img_id), (50,50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            
            cv2.imshow("Cropped_Face",face)
            if cv2.waitKey(1)==13 or int(img_id)==60:
                break
                
    cap.release()
    cv2.destroyAllWindows()
    print("Collecting samples is completed !!!")
    
generate_dataset()
# Out:
# C:\Users\Aanchal Tiwari\AppData\Local\Temp\ipykernel_19508\826755047.py:8: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   if faces == ():
# Collecting samples is completed !!!

# %% [markdown]
# ## Create Label

# %%
import numpy as np # pip install numpy

# %%
def my_label(image_name):
    name=image_name.split('.')[-3]  #aanchal.1.jpg  after split- aanchal 1 jpg
    #if you have two person in your dataset
#    if name=="user1":
#        return np.array([1,0])
#    elif name=="user2":
#        return np.array([0,1])
    
    
    #if you have three person in your dataset
    if name=="user1":
        return np.array([1,0,0])
    elif name=="user2":
        return np.array([0,1,0])
    elif name=="user3":
        return np.array([0,0,1])

# %%
import os
from random import shuffle
from tqdm import tqdm
import cv2
import numpy as np

# %%
def my_data():
    data=[]
    for img in tqdm(os.listdir("data")):
        path=os.path.join("data",img)
        img_data=cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        img_data=cv2.resize(img_data, (50,50))
        data.append([np.array(img_data), my_label(img)])
    shuffle(data)   #1,2,3,4 --> 2,4,3,1
    return data

# %%
data=my_data()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:06<00:00, 94.39it/s]

# %%
train=data[:540]
test=data[540:]
x_train=np.array([i[0] for i in train]).reshape(-1,50,50,1)
print(x_train.shape)
y_train=([i[1] for i in train])

x_test=np.array([i[0] for i in test]).reshape(-1,50,50,1)
print(x_test.shape)
y_test=[i[1] for i in test]
# Out:
# (540, 50, 50, 1)
# (60, 50, 50, 1)

# %% [markdown]
# ## Creating Model

# %%
import tensorflow as tf
from tensorflow.python.framework import ops
import tflearn
from tensorflow.python.framework.graph_util import convert_variables_to_constants
from keras import backend as K
from tflearn.layers.conv import conv_2d, max_pool_2d
from tflearn.layers.core import input_data, dropout, fully_connected
from tflearn.layers.estimator import regression

# %%
ops.reset_default_graph()
#tf.reset_default_graph()
convnet = input_data(shape=[50,50,1])
convnet = conv_2d(convnet, 32, 5, activation='relu')
# 32 filters and stride=5 so that the filter will move 5 pixel or unit at a time
convnet = max_pool_2d(convnet, 5)
convnet = conv_2d(convnet, 64, 5, activation='relu')
convnet = max_pool_2d(convnet, 5)
convnet = conv_2d(convnet, 128, 5, activation='relu')
convnet = max_pool_2d(convnet, 5)
convnet = conv_2d(convnet, 64, 5, activation='relu')
convnet = max_pool_2d(convnet, 5)
convnet = conv_2d(convnet, 32, 5, activation='relu')
convnet = max_pool_2d(convnet, 5)

convnet = fully_connected(convnet, 1024, activation='relu')
convnet = dropout(convnet, 0.8)
convnet = fully_connected(convnet, 3, activation='softmax')
convnet = regression(convnet, optimizer='adam', learning_rate = 0.001, loss='categorical_crossentropy')
model = tflearn.DNN(convnet, tensorboard_verbose=1)
model.fit(x_train, y_train, n_epoch=12, validation_set=(x_test, y_test), show_metric = True, run_id="FRS" )
# Out:
# Training Step: 107  | total loss: 0.10635 | time: 0.583s
# | Adam | epoch: 012 | loss: 0.10635 - acc: 0.9892 -- iter: 512/540
# Training Step: 108  | total loss: 0.57089 | time: 1.683s
# | Adam | epoch: 012 | loss: 0.57089 - acc: 0.9278 | val_loss: 0.01928 - val_acc: 1.0000 -- iter: 540/540
# --

# %%
def data_for_visualization():
    Vdata = []
    for img in tqdm(os.listdir("Images for visualization")):
        path = os.path.join("Images for visualization", img)
        img_num = img.split('.')[0] 
        img_data = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        img_data = cv2.resize(img_data, (50,50))
        Vdata.append([np.array(img_data), img_num])
    shuffle(Vdata)
    return Vdata

# %%
Vdata = data_for_visualization()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 60/60 [00:00<00:00, 73.45it/s]

# %%
import matplotlib.pyplot as plt   # pip install matplotlib

fig = plt.figure(figsize=(20,20))
for num, data in enumerate(Vdata[:20]):
    img_data = data[0]
    y = fig.add_subplot(5,5, num+1)
    image = img_data
    data = img_data.reshape(50,50,1)
    model_out = model.predict([data])[0]
    
    if np.argmax(model_out) == 0:
        my_label = 'user1'
    elif np.argmax(model_out) == 1:
        my_label = 'user2'
    else:
        my_label = 'user3'
        
    y.imshow(image, cmap='gray')
    plt.title(my_label)
    
    y.axes.get_xaxis().set_visible(False)
    y.axes.get_yaxis().set_visible(False)
plt.show()
